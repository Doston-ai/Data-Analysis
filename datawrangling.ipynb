# %% [markdown]
# #1-topshiriq
# 1. Pandas kutubxonasidan foydalanib, quyida berilgan link ichidan barcha jadvallarni o‘qing va roʻyxat shaklida saqlang.
#  * https://en.wikipedia.org/wiki/Fossil_fuel_exporters
# 2. Har bir jadvalning birinchi 1 qatorini ekranga chiqaring.

# %%
import pandas as pd
import numpy as np
import json

# %%
for i, df in enumerate(dfs):
    print(f"\n--- {i+1}-jadval ---")
    print(df.head())
# Out:
# --- 1-jadval ---
#     0                                                  1
# 0 NaN  This article needs to be updated. Please help ...
#
# --- 2-jadval ---
#    Rank Country/region                       Oil - exports Date of information
# 0     1   Saudi Arabia  6,658,642 bbl/d (1,058,639.5 m3/d)           2020 est.
# 1     2         Russia      4,653,500 bbl/d (739,850 m3/d)           2020 est.
# 2     3           Iraq    3,428,379 bbl/d (545,068.7 m3/d)           2020 est.
# 3     4         Canada    3,037,668 bbl/d (482,950.6 m3/d)                2020
# 4     5           Iran      2,700,000 bbl/d (430,000 m3/d)           2021 est.
#
# --- 3-jadval ---
#    Rank Country/region  Natural gas - exports (cu m) Date of information
# 0     1         Russia                  199928345000           2020 est.
# 1     2  United States                  149538000000           2020 est.
# 2     3          Qatar                  143700000000           2020 est.
# 3     4         Norway                  112951000000           2020 est.
# 4     5      Australia                  102262000000           2020 est.
#
# --- 4-jadval ---
#    Rank       Country  Coal - exports (thousand short tons)  \
# 0     1     Indonesia                                451520
# 1     2     Australia                                429894
# 2     3        Russia                                244312
# 3     4  South Africa                                 82573
# 4     5      Colombia                                 74775
#
#    Date of information
# 0                 2020
# 1                 2020
# 2                 2020
# 3                 2020
# 4                 2020
#
# --- 5-jadval ---
#   vteLists of countries by energy rankings  \
# 0                              Fossil Fuel
# 1                                Petroleum
# 2                              Natural gas
# 3                                     Coal
# 4                                  Nuclear
#
#           vteLists of countries by energy rankings.1
# 0  Petroleum All Production Consumption Exports I...
# 1  All Production Consumption Exports Imports Res...
# 2  All Production Consumption Exports Imports Res...
# 3                Reserves Production Exports Imports
# 4  Uranium All Production Generation Reserves Tho...
#
# --- 6-jadval ---
#              0                                                  1
# 0    Petroleum  All Production Consumption Exports Imports Res...
# 1  Natural gas  All Production Consumption Exports Imports Res...
# 2         Coal                Reserves Production Exports Imports
#
# --- 7-jadval ---
#          0                                   1
# 0  Uranium  All Production Generation Reserves
# 1  Thorium                            Reserves

# %%
#javobni shu yerda yozing.
dfs = pd.read_html("https://en.wikipedia.org/wiki/Fossil_fuel_exporters")
dfs[2]
# Out:
#    Rank Country/region  Natural gas - exports (cu m) Date of information
# 0     1         Russia                  199928345000           2020 est.
# 1     2  United States                  149538000000           2020 est.
# 2     3          Qatar                  143700000000           2020 est.
# 3     4         Norway                  112951000000           2020 est.
# 4     5      Australia                  102262000000           2020 est.
# 5     6         Canada                   70932000000           2020 est.
# 6     7        Germany                   50092000000           2020 est.
# 7     8    Netherlands                   39976000000           2020 est.
# 8     9        Algeria                   39459000000           2020 est.
# 9    10        Nigeria                   35586138000           2020 est.

# %% [markdown]
# #2-topshiriq
# Yuqorida yaratilgan jadvallar roʻyxatidan eng uzunini `largest_data.csv` fayliga saqlang.

# %%
#javobni shu yerda yozing.
for i, df in enumerate(dfs):
  print(f"-----{i+1}--------\n")

  print(f"{df.memory_usage(deep=True).sum()}")

dfs[2].to_csv("df2.csv")
# Out:
# -----1--------
#
# 332
# -----2--------
#
# 2626
# -----3--------
#
# 1599
# -----4--------
#
# 1034
# -----5--------
#
# 2190
# -----6--------
#
# 672
# -----7--------
#
# 416

# %% [markdown]
# #3-topshiriq
# 1. Quyidagi link orqali json maʼlumotni yuklab oling va uni climate_change_co2.json nomi bilan saqlang.
#  * https://raw.githubusercontent.com/alishermutalov/praktikum-datasets/refs/heads/praktikum/json_data.json
# 2. Maʼlumotlar boshidan 5 ta qatorni ekranga chiqaring!

# %%
url = "https://raw.githubusercontent.com/alishermutalov/praktikum-datasets/refs/heads/praktikum/json_data.json"
#javobni shu yerda yozing.
df = pd.read_json(url)
df.to_json("climate_change_co2.json")
df.head()
# Out:
#    Year  Total  Gas Fuel  Liquid Fuel  Solid Fuel  Cement  Gas Flaring  \
# 0  2010   9167      1702         3114        3842     450           59
# 1  2009   8740      1585         3056        3620     413           66
# 2  2008   8783      1631         3122        3571     388           71
# 3  2007   8566      1572         3081        3464     382           68
# 4  2006   8370      1525         3089        3339     356           61
#
#    Per Capita
# 0        1.33
# 1        1.28
# 2        1.30
# 3        1.28
# 4        1.27

# %% [markdown]
# #4-topshiriq
# 1. Quyida berilgan linkga `get` soʻrovini yuborish orqali `json` maʼlumotlarini `posts.json` fayliga saqlang.
#   * https://jsonplaceholder.typicode.com/posts/
# 2. Ushbu maʼlumotlarni dataframe koʻrinishida saqlang va tasodifiy 5 ta qatorni ekranga chiqaring.

# %%
import requests
url = "https://jsonplaceholder.typicode.com/posts/"
#javobni shu yerga yozing.
qabul_data = requests.get(url)
data = qabul_data.json()

with open("posts.json", "w") as f:
  json.dump(data, f)

df_posts = pd.DataFrame(data)
display(df_posts.sample(5))
# Out:
#     userId  id                                              title  \
# 85       9  86                         placeat quia et porro iste
# 26       3  27              quasi id et eos tenetur aut quo autem
# 88       9  89           sint soluta et vel magnam aut ut sed qui
# 44       5  45  ut numquam possimus omnis eius suscipit laudan...
# 72       8  73  consequuntur deleniti eos quia temporibus ab a...
#
#                                                  body
# 85  quasi excepturi consequatur iste autem tempori...
# 26  eum sed dolores ipsam sint possimus debitis oc...
# 88  repellat aut aperiam totam temporibus autem et...
# 44  est natus reiciendis nihil possimus aut provid...
# 72  voluptatem cumque tenetur consequatur expedita...
